# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt comet_ml  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v7.0-356-g2070b303 Python-3.10.12 torch-2.3.1+cu121 CPU
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.8/107.7 GB disk)

# %%
# !unzip /content/data_train.zip -d /content/
# Out:
# Archive:  /content/data_train.zip
#    creating: /content/data_train/images/
#    creating: /content/data_train/images/train/
#   inflating: /content/data_train/images/train/cat.1.jpg
#   inflating: /content/data_train/images/train/cat.10.jpg
#   inflating: /content/data_train/images/train/cat.11.jpg
#   inflating: /content/data_train/images/train/cat.12.jpg
#   inflating: /content/data_train/images/train/cat.13.jpg
#   inflating: /content/data_train/images/train/cat.14.jpg
#   inflating: /content/data_train/images/train/cat.15.jpg
#   inflating: /content/data_train/images/train/cat.16.jpg
#   inflating: /content/data_train/images/train/cat.17.jpg
#   inflating: /content/data_train/images/train/cat.18.jpg
#   inflating: /content/data_train/images/train/cat.19.jpg
#   inflating: /content/data_train/images/train/cat.2.jpg
#   inflating: /content/data_train/images/train/cat.20.jpg
#   inflating: /content/data_train/images/train/cat.21.jpg
# ...

# %%
# Train YOLOv5s on COCO128 for 3 epochs
# !python train.py --img 640 --batch 16 --epochs 50 --data /content/yolov5/data/custom_data.yaml --weights yolov5s.pt --cache
# Out:
# 2024-08-23 11:45:59.764581: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:485] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-08-23 11:45:59.802421: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:8454] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-08-23 11:45:59.813689: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1452] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# ...

# %%
# !unzip /content/data_test.zip -d /content/
# Out:
# Archive:  /content/data_test.zip
#   inflating: /content/data_test/cat.177.jpg
#   inflating: /content/data_test/cat.178.jpg
#   inflating: /content/data_test/cat.179.jpg
#   inflating: /content/data_test/cat.180.jpg
#   inflating: /content/data_test/cat.181.jpg
#   inflating: /content/data_test/cat.182.jpg
#   inflating: /content/data_test/cat.183.jpg
#   inflating: /content/data_test/cat.184.jpg
#   inflating: /content/data_test/cat.185.jpg
#   inflating: /content/data_test/cat.186.jpg
#   inflating: /content/data_test/cat.187.jpg
#   inflating: /content/data_test/cat.188.jpg
#   inflating: /content/data_test/cat.189.jpg
#   inflating: /content/data_test/cat.190.jpg
#   inflating: /content/data_test/cat.191.jpg
#   inflating: /content/data_test/cat.192.jpg
#   inflating: /content/data_test/cat.193.jpg
#   inflating: /content/data_test/cat.194.jpg
#   inflating: /content/data_test/cat.195.jpg
#   inflating: /content/data_test/cat.196.jpg
# ...

# %%
# !python detect.py --weights /content/yolov5/runs/train/exp/weights/best.pt --img 640 --conf 0.25 --source /content/data_test/
# Out:
# detect: weights=['/content/yolov5/runs/train/exp/weights/best.pt'], source=/content/data_test/, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-356-g2070b303 Python-3.10.12 torch-2.3.1+cu121 CPU
#
# Fusing layers...
# Model summary: 157 layers, 7015519 parameters, 0 gradients, 15.8 GFLOPs
# image 1/52 /content/data_test/cat.177.jpg: 448x640 1 cat, 257.1ms
# image 2/52 /content/data_test/cat.178.jpg: 512x640 1 cat, 290.7ms
# image 3/52 /content/data_test/cat.179.jpg: 512x640 1 cat, 285.1ms
# image 4/52 /content/data_test/cat.180.jpg: 640x448 1 dog, 1 cat, 263.9ms
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !cp -r /content/yolov5 /content/drive/MyDrive/Colab/YOLOV5

# %%
# !cp -r /content/data_test /content/drive/MyDrive/Colab/YOLOV5

# %%
# !cp -r /content/data_train /content/drive/MyDrive/Colab/YOLOV5
